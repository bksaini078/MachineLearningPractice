# %% [markdown]
# # Deep learning from Scratch in python

# %% [markdown]
# # Fundamentals

# %%
import numpy as np

# %% [markdown]
# ## A single neuron
#
# <img src="attachment:6f899cea-70e2-4ec1-8ace-df589bcbb293.png" width="150"/>

# %%
inputs= [1,2,3,2.5]
weights=[0.2,0.8,-0.5,1.0]
bias=2.0
output=0
for i,w in zip(inputs,weights):
    
    output+=i*w
output+=bias
output
# Out:
# 4.8

# %%
# adding 3 layers
inputs= np.random.randint(10,size=4)
print(f'inputs:{inputs}')
weights1=np.random.randn(len(inputs))
weights2=np.random.randn(len(inputs))
weights3=np.random.randn(len(inputs))
print(f'weights1:{weights1}')
print(f'weights2:{weights2}')
print(f'weights3:{weights3}')
bias=[1,2,3]

output=0
# calculating output
for w in [weights1,weights2,weights3]:
    for i,wt in zip(inputs,w):
        output+=
# Out:
# inputs:[1 5 7 1]
# weights1:[ 0.71677055 -1.81081638 -1.34986808  0.22480515]
# weights2:[-0.70267388 -1.09838889  0.75045681  0.00738194]
# weights3:[-0.76649792 -0.02126393  0.53602752 -0.41005392]
# [ 0.71677055 -1.81081638 -1.34986808  0.22480515]
# [-0.70267388 -1.09838889  0.75045681  0.00738194]
# [-0.76649792 -0.02126393  0.53602752 -0.41005392]

# %%
inputs.shape
# Out:
# (4,)
